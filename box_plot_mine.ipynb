# %% [markdown]
# <a href="https://colab.research.google.com/github/Sru-j/daily_lab_activities/blob/main/box_plot_mine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #load the data via url

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/bkeerthana/MLC/refs/heads/main/MLC_22_cereal.csv'
df= pd.read_csv(url)

# %% [markdown]
# #data inspection

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.shape
# Out:
# (77, 16)

# %%
df.dtypes
# Out:
# name         object
# mfr          object
# type         object
# calories      int64
# protein       int64
# fat           int64
# sodium        int64
# fiber       float64
# carbo       float64
# sugars        int64
# potass        int64
# vitamins      int64
# shelf         int64
# weight      float64
# cups        float64
# rating      float64
# dtype: object

# %%
df.describe()
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
df.describe(percentiles=[]).drop('50%')
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# ...

# %% [markdown]
# #visualization

# %%
import matplotlib.pyplot as plt

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='line')
# Out:
# <Axes: >

# %%
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
df.value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#value error
# df.plot(kind='area')

# %%
df.fillna(0)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.sample()
# Out:
#             name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 42  Lucky Charms   G    C       110        2    1     180    0.0   12.0
#
#     sugars  potass  vitamins  shelf  weight  cups     rating
# 42      12      55        25      2     1.0   1.0  26.734515

# %%
#change the negative value to its positive value in df
df[['calories','fat','protein','sodium','fiber','carbo','sugars','potass','vitamins','shelf','weight','cups','rating']].abs()
# Out:
#     calories  fat  protein  sodium  fiber  carbo  sugars  potass  vitamins  \
# 0         70    1        4     130   10.0    5.0       6     280        25
# 1        120    5        3      15    2.0    8.0       8     135         0
# 2         70    1        4     260    9.0    7.0       5     320        25
# 3         50    0        4     140   14.0    8.0       0     330        25
# 4        110    2        2     200    1.0   14.0       8       1        25
# ..       ...  ...      ...     ...    ...    ...     ...     ...       ...
# 72       110    1        2     250    0.0   21.0       3      60        25
# 73       110    1        1     140    0.0   13.0      12      25        25
# 74       100    1        3     230    3.0   17.0       3     115        25
# 75       100    1        3     200    3.0   17.0       3     110        25
# 76       110    1        2     200    1.0   16.0       8      60        25
#
#     shelf  weight  cups     rating
# ...

# %%
df[['rating' , 'calories']].plot(kind='box')
# Out:
# <Axes: >

# %%
df.boxplot(column =['carbo','sugars'],by=['mfr'],figsize=(10,5));

# %%
plt.figure(figsize=(6,4))

df['rating'].plot(kind='box')

plt.title("Rating distribution")
plt.ylabel("Rating")
plt.show()

# %%
df.boxplot(column =['carbo','sugars'])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
plt.boxplot(df["rating"].dropna(), notch=True, labels=["rating"])
plt.title("Rating distribution (Notched box plot)")
plt.ylabel("Rating")
plt.show()
# Out:
# /tmp/ipython-input-12026/2699839737.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(df["rating"].dropna(), notch=True, labels=["rating"])

# %%
plt.figure(figsize=(6,4))

data = df["rating"]
plt.violinplot(data, showmeans=True)

plt.title("Rating distribution")
plt.ylabel("Rating")
plt.xticks([1], ["rating"])   # label the single violin
plt.show()

# %%
plt.figure(figsize=(6,4))

data = df["rating"]
data2 = df["calories"]
plt.violinplot([data,data2],showmeans=True)

plt.title("Rating distribution")
plt.ylabel("Rating")
plt.xticks([1,2], ["rating","Calories"])   # label the single violin
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.boxenplot(x=df["rating"])
plt.title("Boxen Plot of Rating")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.swarmplot(y=df["rating"])   # one variable
plt.title("Swarm plot of Rating")
plt.ylabel("Rating")
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
# matplot lib
plt.figure(figsize=(6,4))

df.boxplot(column="calories", by="rating", grid=False)

plt.title("Calories Across rating")
plt.ylabel("Calories (%)")
plt.suptitle("")
plt.show()

# %%
# Draw a box plot for calories. Identify if outliers exist.
df.boxplot(column="calories", by="mfr", grid=False)
# Out:
# <Axes: title={'center': 'calories'}, xlabel='mfr'>

# %%
# Draw side-by-side box plots for sugars and fiber. Which one has higher spread?
df.boxplot(column=["sugars", "fiber"], by="mfr", grid=False)
# Out:
# array([<Axes: title={'center': 'sugars'}, xlabel='mfr'>,
#        <Axes: title={'center': 'fiber'}, xlabel='mfr'>], dtype=object)

# %%
# Draw box plot of calories grouped by type (Hot/Cold). Which type has higher median calories?
df.boxplot(column="calories", by="type", grid=False)
# Out:
# <Axes: title={'center': 'calories'}, xlabel='type'>

# %%
# Draw box plot of rating grouped by mfr. Which manufacturer shows the highest median rating?
df.boxplot(column="rating", by="mfr", grid=False)
# Out:
# <Axes: title={'center': 'rating'}, xlabel='mfr'>

# %%
# Find outlier cereals in sugars using the IQR rule.
Q1 = df["sugars"].quantile(0.25)
Q3 = df["sugars"].quantile(0.75)
IQR = Q3 - Q1

low = Q1 - 1.5 * IQR
high = Q3 + 1.5 * IQR

outliers = df[(df["sugars"] < low) | (df["sugars"] > high)]
print(outliers[["name", "sugars"]] if "name" in df.columns else outliers[["sugars"]])
# Out:
# Empty DataFrame
# Columns: [name, sugars]
# Index: []

# %%
#how to use scatterplot
import matplotlib.pyplot as plt
plt.scatter(df['calories'],df['sugars'])
plt.xlabel('sugars consumed')
plt.ylabel('calories collected')
plt.title('sugars vs. Calories collected')
plt.show()

# %%
df.plot(kind='scatter',x='calories',y='sugars')
plt.show()

# %%
correlation = df['calories'].corr(df['sugars'])
print(f"Correlation: {correlation}")

# Create the scatter plot using pandas' built-in plotting function which uses matplotlib
df.plot(kind='scatter', x='calories', y='sugars', title=f'Scatter Plot (Correlation: {correlation:.2f})')

# Display the plot
plt.show()
# Out:
# Correlation: 0.5623402898034883

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
mfr_counts=df.mfr.value_counts()
mfr_counts.plot(kind='bar')
# Out:
# <Axes: xlabel='mfr'>

# %%
# 1. Create a horizontal line for each category
plt.hlines(y=df.index, xmin=df['calories'], xmax=df['sugars'], color='grey', alpha=0.4)

# 2. Add dots for 'calories'
plt.scatter(df['calories'], df.index, color='skyblue', label='Calories', s=100)

# 3. Add dots for 'sugars'
plt.scatter(df['sugars'], df.index, color='orange', label='Sugars', s=100)

plt.legend()
plt.xlabel('Value')
plt.legend(loc = 'lower right')
plt.ylabel('Category Index')
plt.show()

# %%
df.columns
# Out:
# Index(['name', 'mfr', 'type', 'calories', 'protein', 'fat', 'sodium', 'fiber',
#        'carbo', 'sugars', 'potass', 'vitamins', 'shelf', 'weight', 'cups',
#        'rating'],
#       dtype='object')

# %%
#alpha to darken the bubbles , ranging from 0(light) to 1(dark)
df.plot(kind='scatter',x='calories',y='sugars',s=df['protein'], alpha=0.9)
# Out:
# <Axes: xlabel='calories', ylabel='sugars'>

# %%
# Plot Maths marks
plt.plot(df['calories'], df['sugars'])

# plot Science marks
plt.plot(df['calories'], df['fat'])

# Adding Labels
plt.xlabel('calories')
plt.ylabel('sugars and fat')

plt.legend(['sugar', 'fat'])

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.plot(df['calories'], df['sugars'], marker='s', c='b', ls='-', lw=2, ms=8, mew=1, mec='white')
#ms - marker size
#mew - marker edge width
#mec - marker edge color
plt.plot(df['calories'], df['fat'], marker='o', c='r', ls='--', lw=3, ms=10, alpha=.2 )

plt.xlabel('calories')
plt.ylabel('sugars Vs fat')

plt.title("calories")
plt.legend(['sugars', 'fat']);

# To add grid
#line style are : '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'
plt.grid(color='#95a5a6', linestyle='dashdot', linewidth=2, axis='y', alpha=0.1)

# %%
df.plot(kind ='bar',subplots=True)
#plt.figure(figsize=(1.90,1.90))
# Out:
# array([<Axes: title={'center': 'calories'}>,
#        <Axes: title={'center': 'protein'}>,
#        <Axes: title={'center': 'fat'}>,
#        <Axes: title={'center': 'sodium'}>,
#        <Axes: title={'center': 'fiber'}>,
#        <Axes: title={'center': 'carbo'}>,
#        <Axes: title={'center': 'sugars'}>,
#        <Axes: title={'center': 'potass'}>,
#        <Axes: title={'center': 'vitamins'}>,
#        <Axes: title={'center': 'shelf'}>,
#        <Axes: title={'center': 'weight'}>,
#        <Axes: title={'center': 'cups'}>,
#        <Axes: title={'center': 'rating'}>], dtype=object)

# %%
df.plot(kind ='box',subplots=True)
# Out:
# calories       Axes(0.125,0.11;0.0503247x0.77)
# protein      Axes(0.18539,0.11;0.0503247x0.77)
# fat         Axes(0.245779,0.11;0.0503247x0.77)
# sodium      Axes(0.306169,0.11;0.0503247x0.77)
# fiber       Axes(0.366558,0.11;0.0503247x0.77)
# carbo       Axes(0.426948,0.11;0.0503247x0.77)
# sugars      Axes(0.487338,0.11;0.0503247x0.77)
# potass      Axes(0.547727,0.11;0.0503247x0.77)
# vitamins    Axes(0.608117,0.11;0.0503247x0.77)
# shelf       Axes(0.668506,0.11;0.0503247x0.77)
# weight      Axes(0.728896,0.11;0.0503247x0.77)
# cups        Axes(0.789286,0.11;0.0503247x0.77)
# rating      Axes(0.849675,0.11;0.0503247x0.77)
# dtype: object

# %%
# To change the size of the figure
plt.figure(figsize=(0.90, 0.90))
plt.plot(df['calories'], df['sugars'])
plt.plot(df['calories'], df['fat'])

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
# 1. Create the vertical lines (the sticks)
plt.vlines(x=df.index, ymin=0, ymax=df['sugars'], color='skyblue')

# 2. Add the dots at the top (the candy)
plt.scatter(df.index, df['sugars'], color='blue', s=100)

plt.show()

# %%
# !pip install pywaffle

# %%
from pywaffle import Waffle
import matplotlib.pyplot as plt

data = {'Calories': 40, 'Sugars': 30, 'Fiber': 30}
custom_colors = ['chocolate', '#ff9800', '#4caf50'] # Example colors
plt.figure(
    FigureClass=Waffle,
    rows=5,
    colors=custom_colors,
    values=data,
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)}
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
plt.figure(figsize=(15,10))

corrMatrix = df.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-12026/990590234.py in <cell line: 0>()
#       1 plt.figure(figsize=(15,10))
#       2
# ----> 3 corrMatrix = df.corr()
#       4 sns.heatmap(corrMatrix, annot=True)
#       5 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
import numpy as np
# 1. Prepare angles for the circle
n_points = len(df)
angles = np.linspace(0, 2 * np.pi, n_points, endpoint=False)

# 2. Create the plot with polar projection
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})

# 3. Plot the data (using 'sugars' as the radius)
ax.bar(angles, df['calories'], width=0.5, color='teal', alpha=0.7, edgecolor='black')

# 4. Clean up labels
ax.set_xticks(angles)
ax.set_xticklabels(df['name']) # Or df['category_column']

plt.show()
