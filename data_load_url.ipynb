# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/bkeerthana/MLC/refs/heads/main/Lab2_sample_files/superstore.csv"
df = pd.read_csv(url)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
new_columns=['row_id','order_id','order_date','ship_date','ship_mode','customer_id','customer_name','segment','country','city','state','postal_code','region','product_id','category','sub_category','product_name','sales','quantity','discount','profit']

# %%
df.columns = new_columns
df.columns
# Out:
# Index(['row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# row_id             int64
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_id       object
# customer_name     object
# segment           object
# country           object
# city              object
# state             object
# postal_code        int64
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales            float64
# quantity           int64
# discount         float64
# profit           float64
# dtype: object

# %%
df.head()
# Out:
#    row_id        order_id  order_date   ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 1       2  CA-2016-152156  11-08-2016  11-11-2016    Second Class    CG-12520
# 2       3  CA-2016-138688  06-12-2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10-11-2015  10/18/2015  Standard Class    SO-20335
#
#      customer_name    segment        country             city  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   postal_code  region       product_id         category sub_category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         product_name     sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.sample()
# Out:
#       row_id        order_id  order_date   ship_date       ship_mode  \
# 8622    8623  US-2016-114230  11/27/2016  12-01-2016  Standard Class
#
#      customer_id customer_name   segment        country     city  ...  \
# 8622    CM-12235  Chris McAfee  Consumer  United States  Phoenix  ...
#
#      postal_code  region       product_id         category sub_category  \
# 8622       85023    West  OFF-ST-10000876  Office Supplies      Storage
#
#                      product_name   sales  quantity  discount  profit
# 8622  Eldon Simplefile Box Office  39.808         4       0.2  3.9808
#
# [1 rows x 21 columns]

# %%
df['order_date'] = df['order_date'].astype('datetime64[ns]')
df.dtypes['order_date']
# Out:
# dtype('<M8[ns]')

# %%
df['ship_date'] = df['ship_date'].astype('datetime64[ns]')
df.dtypes['ship_date']
# Out:
# dtype('<M8[ns]')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   row_id         9994 non-null   int64
#  1   order_id       9994 non-null   object
#  2   order_date     9994 non-null   datetime64[ns]
#  3   ship_date      9994 non-null   datetime64[ns]
#  4   ship_mode      9994 non-null   object
#  5   customer_id    9994 non-null   object
#  6   customer_name  9994 non-null   object
#  7   segment        9994 non-null   object
#  8   country        9994 non-null   object
#  9   city           9994 non-null   object
#  10  state          9994 non-null   object
#  11  postal_code    9994 non-null   int64
#  12  region         9994 non-null   object
#  13  product_id     9994 non-null   object
#  14  category       9994 non-null   object
#  15  sub_category   9994 non-null   object
#  16  product_name   9994 non-null   object
#  17  sales          9994 non-null   float64
#  18  quantity       9994 non-null   int64
#  19  discount       9994 non-null   float64
#  20  profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# row_id           0
# order_id         0
# order_date       0
# ship_date        0
# ship_mode        0
# customer_id      0
# customer_name    0
# segment          0
# country          0
# city             0
# state            0
# postal_code      0
# region           0
# product_id       0
# category         0
# sub_category     0
# product_name     0
# sales            0
# quantity         0
# discount         0
# profit           0
# dtype: int64

# %% [markdown]
# data access

# %%
#3rd row all content zero means 1st row
df.iloc[3]
# Out:
# row_id                                                       4
# order_id                                        US-2015-108966
# order_date                                 2015-10-11 00:00:00
# ship_date                                  2015-10-18 00:00:00
# ship_mode                                       Standard Class
# customer_id                                           SO-20335
# customer_name                                   Sean O'Donnell
# segment                                               Consumer
# country                                          United States
# city                                           Fort Lauderdale
# state                                                  Florida
# postal_code                                              33311
# region                                                   South
# product_id                                     FUR-TA-10000577
# category                                             Furniture
# sub_category                                            Tables
# product_name     Bretford CR4500 Series Slim Rectangular Table
# sales                                                 957.5775
# quantity                                                     5
# discount                                                  0.45
# profit                                                -383.031
# Name: 3, dtype: object

# %%
#1st row product name
df.iloc[0]['product_name']
# Out:
# 'Bush Somerset Collection Bookcase'

# %%
#all the order_id
df['order_id']
# Out:
# 0       CA-2016-152156
# 1       CA-2016-152156
# 2       CA-2016-138688
# 3       US-2015-108966
# 4       US-2015-108966
#              ...
# 9989    CA-2014-110422
# 9990    CA-2017-121258
# 9991    CA-2017-121258
# 9992    CA-2017-121258
# 9993    CA-2017-119914
# Name: order_id, Length: 9994, dtype: object

# %%
#order id of 4th row
df['order_id'][4]
# Out:
# 'US-2015-108966'

# %%
df[ ['customer_id','country'] ]
# Out:
#      customer_id        country
# 0       CG-12520  United States
# 1       CG-12520  United States
# 2       DV-13045  United States
# 3       SO-20335  United States
# 4       SO-20335  United States
# ...          ...            ...
# 9989    TB-21400  United States
# 9990    DB-13060  United States
# 9991    DB-13060  United States
# 9992    DB-13060  United States
# 9993    CC-12220  United States
#
# [9994 rows x 2 columns]

# %%
#print the rows from 2nd to 9th row with all the columns
#(10-2 = 8 rows)
df.iloc[2:10,]
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#      customer_name    segment        country             city  ...  \
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 5  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 6  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 7  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 8  Brosina Hoffman   Consumer  United States      Los Angeles  ...
# 9  Brosina Hoffman   Consumer  United States      Los Angeles  ...
#
#   postal_code  region       product_id         category sub_category  \
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7       90032    West  TEC-PH-10002275       Technology       Phones
# 8       90032    West  OFF-BI-10003910  Office Supplies      Binders
# 9       90032    West  OFF-AP-10002892  Office Supplies   Appliances
#
#                                         product_name     sales  quantity  \
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
# 5  Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                         Newell 322    7.2800         4
# 7                     Mitel 5320 IP Phone VoIP phone  907.1520         6
# 8  DXL Angle-View Binders with Locking Rings by S...   18.5040         3
# 9                   Belkin F5C206VTEL 6 Outlet Surge  114.9000         5
#
#    discount    profit
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
# 5      0.00   14.1694
# 6      0.00    1.9656
# 7      0.20   90.7152
# 8      0.20    5.7825
# 9      0.00   34.4700
#
# [8 rows x 21 columns]

# %%
#print the rows from 2nd to 15th row with columns from 2nd to 15th only , not all the columns
#(15-2 = 13rows) (16-2 = 14columns)
df.iloc[2:15,2:16]
# Out:
#    order_date  ship_date       ship_mode customer_id    customer_name  \
# 2  2016-06-12 2016-06-16    Second Class    DV-13045  Darrin Van Huff
# 3  2015-10-11 2015-10-18  Standard Class    SO-20335   Sean O'Donnell
# 4  2015-10-11 2015-10-18  Standard Class    SO-20335   Sean O'Donnell
# 5  2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 6  2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 7  2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 8  2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 9  2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 10 2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 11 2014-06-09 2014-06-14  Standard Class    BH-11710  Brosina Hoffman
# 12 2017-04-15 2017-04-20  Standard Class    AA-10480     Andrew Allen
# 13 2016-12-05 2016-12-10  Standard Class    IM-15070     Irene Maddox
# 14 2015-11-22 2015-11-26  Standard Class    HP-14815    Harold Pawlan
#
#         segment        country             city           state  postal_code  \
# 2     Corporate  United States      Los Angeles      California        90036
# 3      Consumer  United States  Fort Lauderdale         Florida        33311
# 4      Consumer  United States  Fort Lauderdale         Florida        33311
# 5      Consumer  United States      Los Angeles      California        90032
# 6      Consumer  United States      Los Angeles      California        90032
# 7      Consumer  United States      Los Angeles      California        90032
# 8      Consumer  United States      Los Angeles      California        90032
# 9      Consumer  United States      Los Angeles      California        90032
# 10     Consumer  United States      Los Angeles      California        90032
# 11     Consumer  United States      Los Angeles      California        90032
# 12     Consumer  United States          Concord  North Carolina        28027
# 13     Consumer  United States          Seattle      Washington        98103
# 14  Home Office  United States       Fort Worth           Texas        76106
#
#      region       product_id         category sub_category
# 2      West  OFF-LA-10000240  Office Supplies       Labels
# 3     South  FUR-TA-10000577        Furniture       Tables
# 4     South  OFF-ST-10000760  Office Supplies      Storage
# 5      West  FUR-FU-10001487        Furniture  Furnishings
# 6      West  OFF-AR-10002833  Office Supplies          Art
# 7      West  TEC-PH-10002275       Technology       Phones
# 8      West  OFF-BI-10003910  Office Supplies      Binders
# 9      West  OFF-AP-10002892  Office Supplies   Appliances
# 10     West  FUR-TA-10001539        Furniture       Tables
# 11     West  TEC-PH-10002033       Technology       Phones
# 12    South  OFF-PA-10002365  Office Supplies        Paper
# 13     West  OFF-BI-10003656  Office Supplies      Binders
# 14  Central  OFF-AP-10002311  Office Supplies   Appliances

# %%
#last row values

df.iloc[-1]
# Out:
# row_id                                                        9994
# order_id                                            CA-2017-119914
# order_date                                     2017-05-04 00:00:00
# ship_date                                      2017-05-09 00:00:00
# ship_mode                                             Second Class
# customer_id                                               CC-12220
# customer_name                                         Chris Cortes
# segment                                                   Consumer
# country                                              United States
# city                                                   Westminster
# state                                                   California
# postal_code                                                  92683
# region                                                        West
# product_id                                         OFF-AP-10002684
# category                                           Office Supplies
# sub_category                                            Appliances
# product_name     Acco 7-Outlet Masterpiece Power Center, Wihtou...
# sales                                                       243.16
# quantity                                                         2
# discount                                                       0.0
# profit                                                      72.948
# Name: 9993, dtype: object

# %%
# first 3 row values

df.iloc[0:3]
# Out:
#    row_id        order_id order_date  ship_date     ship_mode customer_id  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11  Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16  Second Class    DV-13045
#
#      customer_name    segment        country         city  ... postal_code  \
# 0      Claire Gute   Consumer  United States    Henderson  ...       42420
# 1      Claire Gute   Consumer  United States    Henderson  ...       42420
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  ...       90036
#
#    region       product_id         category sub_category  \
# 0   South  FUR-BO-10001798        Furniture    Bookcases
# 1   South  FUR-CH-10000454        Furniture       Chairs
# 2    West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         product_name   sales  quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62         2
#
#    discount    profit
# 0       0.0   41.9136
# 1       0.0  219.5820
# 2       0.0    6.8714
#
# [3 rows x 21 columns]

# %%
#last 2 vaues printing , not print the last line, just 2nd and 3rd last

df.iloc[-3:-1]
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      customer_id customer_name   segment        country        city  ...  \
# 9991    DB-13060   Dave Brooks  Consumer  United States  Costa Mesa  ...
# 9992    DB-13060   Dave Brooks  Consumer  United States  Costa Mesa  ...
#
#      postal_code  region       product_id         category sub_category  \
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
#
#                                            product_name    sales  quantity  \
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
#
#       discount   profit
# 9991       0.2  19.3932
# 9992       0.0  13.3200
#
# [2 rows x 21 columns]

# %%
#last 3 values are prented including the last row

df.iloc[-3:]
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      customer_id customer_name   segment        country         city  ...  \
# 9991    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      postal_code  region       product_id         category sub_category  \
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name    sales  quantity  \
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       discount   profit
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [3 rows x 21 columns]

# %%
df.iloc[3:-1]
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9988    9989  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
#
#      customer_id     customer_name    segment        country             city  \
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5       BH-11710   Brosina Hoffman   Consumer  United States      Los Angeles
# 6       BH-11710   Brosina Hoffman   Consumer  United States      Los Angeles
# 7       BH-11710   Brosina Hoffman   Consumer  United States      Los Angeles
# ...          ...               ...        ...            ...              ...
# 9988    RA-19885      Ruben Ausman  Corporate  United States           Athens
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
#
#       ... postal_code  region       product_id         category sub_category  \
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# 5     ...       90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6     ...       90032    West  OFF-AR-10002833  Office Supplies          Art
# 7     ...       90032    West  TEC-PH-10002275       Technology       Phones
# ...   ...         ...     ...              ...              ...          ...
# 9988  ...       30605   South  TEC-PH-10004006       Technology       Phones
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
#
#                                            product_name     sales  quantity  \
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.8600         7
# 6                                            Newell 322    7.2800         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.1520         6
# ...                                                 ...       ...       ...
# 9988                    Panasonic KX - TS880B Telephone  206.1000         5
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
#
#       discount    profit
# 3         0.45 -383.0310
# 4         0.20    2.5164
# 5         0.00   14.1694
# 6         0.00    1.9656
# 7         0.20   90.7152
# ...        ...       ...
# 9988      0.00   55.6470
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
#
# [9990 rows x 21 columns]

# %%
df[ ['order_id','order_date','ship_date'] ][0:5]
#df[ ['order_id','order_date','ship_date'] ].iloc[0:5]
# Out:
#          order_id order_date  ship_date
# 0  CA-2016-152156 2016-11-08 2016-11-11
# 1  CA-2016-152156 2016-11-08 2016-11-11
# 2  CA-2016-138688 2016-06-12 2016-06-16
# 3  US-2015-108966 2015-10-11 2015-10-18
# 4  US-2015-108966 2015-10-11 2015-10-18

# %%
#zeroth row index

df.iloc[0]
# Out:
# row_id                                           1
# order_date                     2016-11-08 00:00:00
# ship_date                      2016-11-11 00:00:00
# ship_mode                             Second Class
# customer_id                               CG-12520
# customer_name                          Claire Gute
# segment                                   Consumer
# country                              United States
# city                                     Henderson
# state                                     Kentucky
# postal_code                                  42420
# region                                       South
# product_id                         FUR-BO-10001798
# category                                 Furniture
# sub_category                             Bookcases
# product_name     Bush Somerset Collection Bookcase
# sales                                       261.96
# quantity                                         2
# discount                                       0.0
# profit                                     41.9136
# Name: CA-2016-152156, dtype: object

# %% [markdown]
# df.loc USAGE

# %%
#zeroth label row

df.loc[0]
# Out:
# row_id                                        5
# order_id                         US-2015-108966
# order_date                  2015-10-11 00:00:00
# ship_date                   2015-10-18 00:00:00
# ship_mode                        Standard Class
# customer_id                            SO-20335
# customer_name                    Sean O'Donnell
# segment                                Consumer
# country                           United States
# city                            Fort Lauderdale
# state                                   Florida
# postal_code                               33311
# region                                    South
# product_id                      OFF-ST-10000760
# category                        Office Supplies
# sub_category                            Storage
# product_name     Eldon Fold 'N Roll Cart System
# sales                                    22.368
# quantity                                      2
# discount                                    0.2
# profit                                   2.5164
# Name: 4, dtype: object

# %%
# 3rd row 2nd column

df.loc[3,'order_id']
# Out:
# 'US-2015-108966'

# %%
df.sample()
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 3740    3741  CA-2016-133340 2016-12-09 2016-12-13  Standard Class
#
#      customer_id     customer_name   segment        country     city  ...  \
# 3740    LH-17155  Logan Haushalter  Consumer  United States  Jackson  ...
#
#      postal_code   region       product_id         category sub_category  \
# 3740       49201  Central  OFF-AP-10002311  Office Supplies   Appliances
#
#                                            product_name   sales  quantity  \
# 3740  Holmes Replacement Filter for HEPA Air Cleaner...  61.929         1
#
#       discount   profit
# 3740       0.1  23.3954
#
# [1 rows x 21 columns]

# %%
#ZERO AND 4TH ROW

df.loc[[0,3]]
# Out:
#    row_id        order_id order_date  ship_date       ship_mode customer_id  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#     customer_name   segment        country             city  ... postal_code  \
# 0     Claire Gute  Consumer  United States        Henderson  ...       42420
# 3  Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
#
#    region       product_id   category sub_category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 3   South  FUR-TA-10000577  Furniture       Tables
#
#                                     product_name     sales  quantity  \
# 0              Bush Somerset Collection Bookcase  261.9600         2
# 3  Bretford CR4500 Series Slim Rectangular Table  957.5775         5
#
#    discount    profit
# 0      0.00   41.9136
# 3      0.45 -383.0310
#
# [2 rows x 21 columns]

# %%
df.loc[[0,3],'order_id']
# Out:
# 0    CA-2016-152156
# 3    US-2015-108966
# Name: order_id, dtype: object

# %%
df.loc[4,["order_id","country"]]
# Out:
# order_id    US-2015-108966
# country      United States
# Name: 4, dtype: object

# %%
df.loc[[3,7],["order_id","customer_name","country","region"]]
# Out:
#          order_id    customer_name        country region
# 3  US-2015-108966   Sean O'Donnell  United States  South
# 7  CA-2014-115812  Brosina Hoffman  United States   West

# %%
df.set_index("order_id",inplace=True)

# %%
df.iloc[0]
# Out:
# row_id                                           1
# order_date                     2016-11-08 00:00:00
# ship_date                      2016-11-11 00:00:00
# ship_mode                             Second Class
# customer_id                               CG-12520
# customer_name                          Claire Gute
# segment                                   Consumer
# country                              United States
# city                                     Henderson
# state                                     Kentucky
# postal_code                                  42420
# region                                       South
# product_id                         FUR-BO-10001798
# category                                 Furniture
# sub_category                             Bookcases
# product_name     Bush Somerset Collection Bookcase
# sales                                       261.96
# quantity                                         2
# discount                                       0.0
# profit                                     41.9136
# Name: CA-2016-152156, dtype: object

# %%
df
# Out:
#                 row_id order_date  ship_date       ship_mode customer_id  \
# order_id
# CA-2016-152156       1 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-152156       2 2016-11-08 2016-11-11    Second Class    CG-12520
# CA-2016-138688       3 2016-06-12 2016-06-16    Second Class    DV-13045
# US-2015-108966       4 2015-10-11 2015-10-18  Standard Class    SO-20335
# US-2015-108966       5 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...                ...        ...        ...             ...         ...
# CA-2014-110422    9990 2014-01-21 2014-01-23    Second Class    TB-21400
# CA-2017-121258    9991 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258    9992 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-121258    9993 2017-02-26 2017-03-03  Standard Class    DB-13060
# CA-2017-119914    9994 2017-05-04 2017-05-09    Second Class    CC-12220
#
#                    customer_name    segment        country             city  \
# order_id
# CA-2016-152156       Claire Gute   Consumer  United States        Henderson
# CA-2016-152156       Claire Gute   Consumer  United States        Henderson
# CA-2016-138688   Darrin Van Huff  Corporate  United States      Los Angeles
# US-2015-108966    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# US-2015-108966    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...                          ...        ...            ...              ...
# CA-2014-110422  Tom Boeckenhauer   Consumer  United States            Miami
# CA-2017-121258       Dave Brooks   Consumer  United States       Costa Mesa
# CA-2017-121258       Dave Brooks   Consumer  United States       Costa Mesa
# CA-2017-121258       Dave Brooks   Consumer  United States       Costa Mesa
# CA-2017-119914      Chris Cortes   Consumer  United States      Westminster
#
#                      state  postal_code region       product_id  \
# order_id
# CA-2016-152156    Kentucky        42420  South  FUR-BO-10001798
# CA-2016-152156    Kentucky        42420  South  FUR-CH-10000454
# CA-2016-138688  California        90036   West  OFF-LA-10000240
# US-2015-108966     Florida        33311  South  FUR-TA-10000577
# US-2015-108966     Florida        33311  South  OFF-ST-10000760
# ...                    ...          ...    ...              ...
# CA-2014-110422     Florida        33180  South  FUR-FU-10001889
# CA-2017-121258  California        92627   West  FUR-FU-10000747
# CA-2017-121258  California        92627   West  TEC-PH-10003645
# CA-2017-121258  California        92627   West  OFF-PA-10004041
# CA-2017-119914  California        92683   West  OFF-AP-10002684
#
#                        category sub_category  \
# order_id
# CA-2016-152156        Furniture    Bookcases
# CA-2016-152156        Furniture       Chairs
# CA-2016-138688  Office Supplies       Labels
# US-2015-108966        Furniture       Tables
# US-2015-108966  Office Supplies      Storage
# ...                         ...          ...
# CA-2014-110422        Furniture  Furnishings
# CA-2017-121258        Furniture  Furnishings
# CA-2017-121258       Technology       Phones
# CA-2017-121258  Office Supplies        Paper
# CA-2017-119914  Office Supplies   Appliances
#
#                                                      product_name     sales  \
# order_id
# CA-2016-152156                  Bush Somerset Collection Bookcase  261.9600
# CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# CA-2016-138688  Self-Adhesive Address Labels for Typewriters b...   14.6200
# US-2015-108966      Bretford CR4500 Series Slim Rectangular Table  957.5775
# US-2015-108966                     Eldon Fold 'N Roll Cart System   22.3680
# ...                                                           ...       ...
# CA-2014-110422                             Ultra Door Pull Handle   25.2480
# CA-2017-121258  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600
# CA-2017-121258                              Aastra 57i VoIP phone  258.5760
# CA-2017-121258  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000
# CA-2017-119914  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600
#
#                 quantity  discount    profit
# order_id
# CA-2016-152156         2      0.00   41.9136
# CA-2016-152156         3      0.00  219.5820
# CA-2016-138688         2      0.00    6.8714
# US-2015-108966         5      0.45 -383.0310
# US-2015-108966         2      0.20    2.5164
# ...                  ...       ...       ...
# CA-2014-110422         3      0.20    4.1028
# CA-2017-121258         2      0.00   15.6332
# CA-2017-121258         2      0.20   19.3932
# CA-2017-121258         4      0.00   13.3200
# CA-2017-119914         2      0.00   72.9480
#
# [9994 rows x 20 columns]

# %%
#ERROR

 #df.iloc['CA-2016-152156']

# %%
df.loc['CA-2016-152156']
# Out:
#                 row_id order_date  ship_date     ship_mode customer_id  \
# order_id
# CA-2016-152156       1 2016-11-08 2016-11-11  Second Class    CG-12520
# CA-2016-152156       2 2016-11-08 2016-11-11  Second Class    CG-12520
#
#                customer_name   segment        country       city     state  \
# order_id
# CA-2016-152156   Claire Gute  Consumer  United States  Henderson  Kentucky
# CA-2016-152156   Claire Gute  Consumer  United States  Henderson  Kentucky
#
#                 postal_code region       product_id   category sub_category  \
# order_id
# CA-2016-152156        42420  South  FUR-BO-10001798  Furniture    Bookcases
# CA-2016-152156        42420  South  FUR-CH-10000454  Furniture       Chairs
#
#                                                      product_name   sales  \
# order_id
# CA-2016-152156                  Bush Somerset Collection Bookcase  261.96
# CA-2016-152156  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94
#
#                 quantity  discount    profit
# order_id
# CA-2016-152156         2       0.0   41.9136
# CA-2016-152156         3       0.0  219.5820

# %% [markdown]
# UNIVERIATE INSPECTION

# %%
print( df['region'].unique() )
# Out:
# ['South' 'West' 'Central' 'East']

# %%
df['region'].nunique()
# Out:
# 4

# %%
print( df['sales'].unique() )
df['sales'].nunique()
# Out:
# [261.96  731.94   14.62  ... 437.472  97.98  243.16 ]
# 5825

# %%
print( df['segment'].unique() )
df['segment'].nunique()
# Out:
# ['Consumer' 'Corporate' 'Home Office']
# 3

# %%
print( df['state'].unique() )
df['state'].nunique()
# Out:
# ['Kentucky' 'California' 'Florida' 'North Carolina' 'Washington' 'Texas'
#  'Wisconsin' 'Utah' 'Nebraska' 'Pennsylvania' 'Illinois' 'Minnesota'
#  'Michigan' 'Delaware' 'Indiana' 'New York' 'Arizona' 'Virginia'
#  'Tennessee' 'Alabama' 'South Carolina' 'Oregon' 'Colorado' 'Iowa' 'Ohio'
#  'Missouri' 'Oklahoma' 'New Mexico' 'Louisiana' 'Connecticut' 'New Jersey'
#  'Massachusetts' 'Georgia' 'Nevada' 'Rhode Island' 'Mississippi'
#  'Arkansas' 'Montana' 'New Hampshire' 'Maryland' 'District of Columbia'
#  'Kansas' 'Vermont' 'Maine' 'South Dakota' 'Idaho' 'North Dakota'
#  'Wyoming' 'West Virginia']
# 49

# %%
df['region'] == 'West'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9989    False
# 9990     True
# 9991     True
# 9992     True
# 9993     True
# Name: region, Length: 9994, dtype: bool

# %%
df[df["region"]  == "West"]
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 5          6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 6          7  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 7          8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 8          9  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      customer_id    customer_name    segment        country         city  ...  \
# 2       DV-13045  Darrin Van Huff  Corporate  United States  Los Angeles  ...
# 5       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 6       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 7       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# 8       BH-11710  Brosina Hoffman   Consumer  United States  Los Angeles  ...
# ...          ...              ...        ...            ...          ...  ...
# 9986    ML-17410     Maris LaWare   Consumer  United States  Los Angeles  ...
# 9990    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9991    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9992    DB-13060      Dave Brooks   Consumer  United States   Costa Mesa  ...
# 9993    CC-12220     Chris Cortes   Consumer  United States  Westminster  ...
#
#      postal_code  region       product_id         category sub_category  \
# 2          90036    West  OFF-LA-10000240  Office Supplies       Labels
# 5          90032    West  FUR-FU-10001487        Furniture  Furnishings
# 6          90032    West  OFF-AR-10002833  Office Supplies          Art
# 7          90032    West  TEC-PH-10002275       Technology       Phones
# 8          90032    West  OFF-BI-10003910  Office Supplies      Binders
# ...          ...     ...              ...              ...          ...
# 9986       90008    West  TEC-AC-10003399       Technology  Accessories
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name    sales  quantity  \
# 2     Self-Adhesive Address Labels for Typewriters b...   14.620         2
# 5     Eldon Expressions Wood and Plastic Desk Access...   48.860         7
# 6                                            Newell 322    7.280         4
# 7                        Mitel 5320 IP Phone VoIP phone  907.152         6
# 8     DXL Angle-View Binders with Locking Rings by S...   18.504         3
# ...                                                 ...      ...       ...
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.240         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160         2
#
#       discount   profit
# 2          0.0   6.8714
# 5          0.0  14.1694
# 6          0.0   1.9656
# 7          0.2  90.7152
# 8          0.2   5.7825
# ...        ...      ...
# 9986       0.0  15.2208
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480
#
# [3203 rows x 21 columns]

# %%
(df['region'] == 'West').sum()
# Out:
# np.int64(3203)

# %%
df['region'].value_counts()
# Out:
# region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %% [markdown]
# DIVIDE THE CSV INTO DIFFERNT CSV'S

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
west_df = df[df['region'] == 'West']
west_df.to_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_west.csv")
pd.read_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_west.csv").head()
# Out:
#    Unnamed: 0  row_id        order_id  order_date   ship_date       ship_mode  \
# 0           2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 1           5       6  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 2           6       7  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 3           7       8  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
# 4           8       9  CA-2014-115812  2014-06-09  2014-06-14  Standard Class
#
#   customer_id    customer_name    segment        country  ... postal_code  \
# 0    DV-13045  Darrin Van Huff  Corporate  United States  ...       90036
# 1    BH-11710  Brosina Hoffman   Consumer  United States  ...       90032
# 2    BH-11710  Brosina Hoffman   Consumer  United States  ...       90032
# 3    BH-11710  Brosina Hoffman   Consumer  United States  ...       90032
# 4    BH-11710  Brosina Hoffman   Consumer  United States  ...       90032
#
#   region       product_id         category sub_category  \
# 0   West  OFF-LA-10000240  Office Supplies       Labels
# 1   West  FUR-FU-10001487        Furniture  Furnishings
# 2   West  OFF-AR-10002833  Office Supplies          Art
# 3   West  TEC-PH-10002275       Technology       Phones
# 4   West  OFF-BI-10003910  Office Supplies      Binders
#
#                                         product_name    sales quantity  \
# 0  Self-Adhesive Address Labels for Typewriters b...   14.620        2
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.860        7
# 2                                         Newell 322    7.280        4
# 3                     Mitel 5320 IP Phone VoIP phone  907.152        6
# 4  DXL Angle-View Binders with Locking Rings by S...   18.504        3
#
#    discount   profit
# 0       0.0   6.8714
# 1       0.0  14.1694
# 2       0.0   1.9656
# 3       0.2  90.7152
# 4       0.2   5.7825
#
# [5 rows x 22 columns]

# %%
south_df = df[df['region'] == 'South']
south_df.to_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_south.csv")
pd.read_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_south.csv").head()
# Out:
#    Unnamed: 0  row_id        order_id  order_date   ship_date       ship_mode  \
# 0           0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 1           1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 2           3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 3           4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 4          12      13  CA-2017-114412  2017-04-15  2017-04-20  Standard Class
#
#   customer_id   customer_name   segment        country  ... postal_code  \
# 0    CG-12520     Claire Gute  Consumer  United States  ...       42420
# 1    CG-12520     Claire Gute  Consumer  United States  ...       42420
# 2    SO-20335  Sean O'Donnell  Consumer  United States  ...       33311
# 3    SO-20335  Sean O'Donnell  Consumer  United States  ...       33311
# 4    AA-10480    Andrew Allen  Consumer  United States  ...       28027
#
#   region       product_id         category sub_category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# 1  South  FUR-CH-10000454        Furniture       Chairs
# 2  South  FUR-TA-10000577        Furniture       Tables
# 3  South  OFF-ST-10000760  Office Supplies      Storage
# 4  South  OFF-PA-10002365  Office Supplies        Paper
#
#                                         product_name     sales quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600        2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400        3
# 2      Bretford CR4500 Series Slim Rectangular Table  957.5775        5
# 3                     Eldon Fold 'N Roll Cart System   22.3680        2
# 4                                         Xerox 1967   15.5520        3
#
#    discount    profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.45 -383.0310
# 3      0.20    2.5164
# 4      0.20    5.4432
#
# [5 rows x 22 columns]

# %%
east_df = df[df['region'] == 'East']
east_df.to_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_east.csv")
pd.read_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_east.csv").head()
# Out:
#    Unnamed: 0  row_id        order_id  order_date   ship_date       ship_mode  \
# 0          23      24  US-2017-156909  2017-07-16  2017-07-18    Second Class
# 1          27      28  US-2015-150630  2015-09-17  2015-09-21  Standard Class
# 2          28      29  US-2015-150630  2015-09-17  2015-09-21  Standard Class
# 3          29      30  US-2015-150630  2015-09-17  2015-09-21  Standard Class
# 4          30      31  US-2015-150630  2015-09-17  2015-09-21  Standard Class
#
#   customer_id    customer_name   segment        country  ... postal_code  \
# 0    SF-20065  Sandra Flanagan  Consumer  United States  ...       19140
# 1    TB-21520  Tracy Blumstein  Consumer  United States  ...       19140
# 2    TB-21520  Tracy Blumstein  Consumer  United States  ...       19140
# 3    TB-21520  Tracy Blumstein  Consumer  United States  ...       19140
# 4    TB-21520  Tracy Blumstein  Consumer  United States  ...       19140
#
#   region       product_id         category sub_category  \
# 0   East  FUR-CH-10002774        Furniture       Chairs
# 1   East  FUR-BO-10004834        Furniture    Bookcases
# 2   East  OFF-BI-10000474  Office Supplies      Binders
# 3   East  FUR-FU-10004848        Furniture  Furnishings
# 4   East  OFF-EN-10001509  Office Supplies    Envelopes
#
#                                         product_name     sales quantity  \
# 0                 Global Deluxe Stacking Chair, Gray    71.372        2
# 1  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430        7
# 2  Avery Recycled Flexi-View Covers for Binding S...     9.618        2
# 3  Howard Miller 13-3/4" Diameter Brushed Chrome ...   124.200        3
# 4                          Poly String Tie Envelopes     3.264        2
#
#    discount     profit
# 0       0.3    -1.0196
# 1       0.5 -1665.0522
# 2       0.7    -7.0532
# 3       0.2    15.5250
# 4       0.2     1.1016
#
# [5 rows x 22 columns]

# %%
central_df = df[df['region'] == 'Central']
central_df.to_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_central.csv")
pd.read_csv("/content/drive/My Drive/Colab Notebooks/day_10_data/superstore_central.csv").head()
# Out:
#    Unnamed: 0  row_id        order_id  order_date   ship_date       ship_mode  \
# 0          14      15  US-2015-118983  2015-11-22  2015-11-26  Standard Class
# 1          15      16  US-2015-118983  2015-11-22  2015-11-26  Standard Class
# 2          16      17  CA-2014-105893  2014-11-11  2014-11-18  Standard Class
# 3          21      22  CA-2016-137330  2016-12-09  2016-12-13  Standard Class
# 4          22      23  CA-2016-137330  2016-12-09  2016-12-13  Standard Class
#
#   customer_id  customer_name      segment        country  ... postal_code  \
# 0    HP-14815  Harold Pawlan  Home Office  United States  ...       76106
# 1    HP-14815  Harold Pawlan  Home Office  United States  ...       76106
# 2    PK-19075      Pete Kriz     Consumer  United States  ...       53711
# 3    KB-16585      Ken Black    Corporate  United States  ...       68025
# 4    KB-16585      Ken Black    Corporate  United States  ...       68025
#
#     region       product_id         category sub_category  \
# 0  Central  OFF-AP-10002311  Office Supplies   Appliances
# 1  Central  OFF-BI-10000756  Office Supplies      Binders
# 2  Central  OFF-ST-10004186  Office Supplies      Storage
# 3  Central  OFF-AR-10000246  Office Supplies          Art
# 4  Central  OFF-AP-10001492  Office Supplies   Appliances
#
#                                         product_name    sales quantity  \
# 0  Holmes Replacement Filter for HEPA Air Cleaner...   68.810        5
# 1   Storex DuraTech Recycled Plastic Frosted Binders    2.544        3
# 2  Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...  665.880        6
# 3                                         Newell 318   19.460        7
# 4        Acco Six-Outlet Power Strip, 4' Cord Length   60.340        7
#
#    discount    profit
# 0       0.8 -123.8580
# 1       0.8   -3.8160
# 2       0.0   13.3176
# 3       0.0    5.0596
# 4       0.0   15.6884
#
# [5 rows x 22 columns]

# %% [markdown]
# Concatinating

# %%
pd.concat([east_df,south_df, central_df,west_df] , ignore_index= True, sort=False)
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 0         24  US-2017-156909 2017-07-16 2017-07-18    Second Class
# 1         28  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 2         29  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 3         30  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# 4         31  US-2015-150630 2015-09-17 2015-09-21  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9987  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      customer_id    customer_name   segment        country          city  ...  \
# 0       SF-20065  Sandra Flanagan  Consumer  United States  Philadelphia  ...
# 1       TB-21520  Tracy Blumstein  Consumer  United States  Philadelphia  ...
# 2       TB-21520  Tracy Blumstein  Consumer  United States  Philadelphia  ...
# 3       TB-21520  Tracy Blumstein  Consumer  United States  Philadelphia  ...
# 4       TB-21520  Tracy Blumstein  Consumer  United States  Philadelphia  ...
# ...          ...              ...       ...            ...           ...  ...
# 9989    ML-17410     Maris LaWare  Consumer  United States   Los Angeles  ...
# 9990    DB-13060      Dave Brooks  Consumer  United States    Costa Mesa  ...
# 9991    DB-13060      Dave Brooks  Consumer  United States    Costa Mesa  ...
# 9992    DB-13060      Dave Brooks  Consumer  United States    Costa Mesa  ...
# 9993    CC-12220     Chris Cortes  Consumer  United States   Westminster  ...
#
#      postal_code  region       product_id         category sub_category  \
# 0          19140    East  FUR-CH-10002774        Furniture       Chairs
# 1          19140    East  FUR-BO-10004834        Furniture    Bookcases
# 2          19140    East  OFF-BI-10000474  Office Supplies      Binders
# 3          19140    East  FUR-FU-10004848        Furniture  Furnishings
# 4          19140    East  OFF-EN-10001509  Office Supplies    Envelopes
# ...          ...     ...              ...              ...          ...
# 9989       90008    West  TEC-AC-10003399       Technology  Accessories
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            product_name     sales  quantity  \
# 0                    Global Deluxe Stacking Chair, Gray    71.372         2
# 1     Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430         7
# 2     Avery Recycled Flexi-View Covers for Binding S...     9.618         2
# 3     Howard Miller 13-3/4" Diameter Brushed Chrome ...   124.200         3
# 4                             Poly String Tie Envelopes     3.264         2
# ...                                                 ...       ...       ...
# 9989  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...    36.240         1
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...    91.960         2
# 9991                              Aastra 57i VoIP phone   258.576         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"    29.600         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...   243.160         2
#
#       discount     profit
# 0          0.3    -1.0196
# 1          0.5 -1665.0522
# 2          0.7    -7.0532
# 3          0.2    15.5250
# 4          0.2     1.1016
# ...        ...        ...
# 9989       0.0    15.2208
# 9990       0.0    15.6332
# 9991       0.2    19.3932
# 9992       0.0    13.3200
# 9993       0.0    72.9480
#
# [9994 rows x 21 columns]
