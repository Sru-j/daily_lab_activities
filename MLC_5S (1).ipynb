# %% [markdown]
# Recap:
#
#      Machine learning for cybersecurity
#      Applications of Machine learning
#      Cyber
#      Security
#      Cybersecurity
#      Application of Machine learning in cyberecurity
#
#
#      Data
#      Question
#      Information
#      Interpretation
#      Knowledge
#      Decision
#
#
#      Types of Data Analytics
#      Describe
#      Diagnostic
#      Prescriptive
#      predictive
#
#
#      Life cycle of Data Analytics
#      Context
#      problem
#      collect data
#      clean
#      EDA
#      Model
#      Visualize
#      Decision
#
#
#      Types of Data
#        Structure
#        Unstructure
#        Semi-Structure
#
#     Activity:
#
#        Loading files

# %% [markdown]
# Based on Value
#
#
#      Qualitative (Categorical)
#
#      Quantitative (Numerical)

# %% [markdown]
# Activity:
#
#
#
#       The security update was effective and stable.
#
#       The user attempted to log in 13 times within one hour.
#
#       The SOC analyst is alert, detail-oriented, and proactive during incident
#       response.
#
#       The firewall blocked 14 malicious IP addresses this week.
#
#       The system administrator has two-factor authentication enabled and a strong password policy.
#
#       The IT team deployed 7 security patches this month.
#
#       The user behavior appears suspicious but non-malicious.
#
#       The SOC analyst resolved 34 security alerts today.

# %% [markdown]
# Activity:
# | Data Unit                   | Question / Variable                      | Example Value  | Data Type  |
# | --------------------------- | ---------------------------------------- | -------------- | ------------------------------- |
# | **User Account**            | How many login attempts were made today? | 12             | quantity                      |
# |                             | What is the user role?                   | Admin          | quality                      |
# |                             | Session duration                         | 45 minutes     | quantity                      |
# |                             | Was multi-factor authentication enabled? | Yes            | quality                      |
# | **Network Host**            | Average CPU usage                        | 72%            | quantity                      |
# |                             | Operating system                         | Linux          | quality                      |
# |                             | Number of open ports                     | 7              | quantity                      |
# |                             | Host security status                     | Compromised    | quality                      |
# | **Network Flow**            | Total bytes transferred                  | 2.3 MB         | quantity                      |
# |                             | Protocol used                            | TCP            | quality                      |
# |                             | Flow duration                            | 120 seconds    | quantity                      |
# |                             | Traffic direction                        | Inbound        | quality                      |
# | **Log Entry**               | Event timestamp                          | 1704865200     | quantity                      |
# |                             | Event type                               | Authentication | quality                      |
# |                             | Response time                            | 350 ms         | quantity                      |
# |                             | Source country                           | India          | quality                      |
# | **Cyber Attack Instance**   | Attack duration                          | 60 seconds     | quantity                      |
# |                             | Attack type                              | TCP SYN Flood  | quality                      |
# |                             | Packet rate                              | 15,000 pps     | quantity                      |
# |                             | Attack phase                             | Attack         | quality                      |
# | **Security Incident (SOC)** | Number of alerts triggered               | 27             | quantity                      |
# |                             | Incident severity                        | High           | quality                      |
# |                             | Time to detect                           | 4 minutes      | quantity                      |
# |                             | Mitigation status                        | Contained      | quality                      |

# %% [markdown]
# Based on Value
#
#    Qualitative (Categorical)
#
#          Nominal
#          Ordinal
#
#    Quantitative (Numerical)
#
#          Discrete
#          Continuous

# %% [markdown]
# Activity: Decide - Nominal or Ordinal
#
# | Variable / Scenario   | Example Value | Data Type                       |
# | --------------------- | ------------- | ------------------------------- |
# | User role             | Admin         | Nominal                      |
# | Incident severity     | High          | ordinal                      |
# | Attack type           | DDoS          | Nominal                      |
# | Risk level            | Medium        | ordinal                      |
# | Protocol              | TCP           | Nominal                      |
# | Alert priority        | P1            | ordinal                      |
# | Country               | India         | Nominal                      |
# | Threat confidence     | Low           | ordinal                      |
# | Authentication method | MFA           | Nominal                      |
# | Incident status       | Resolved      |nominal                       |

# %% [markdown]
# Activity: Rearrage the order
#
# Rearrange the following values in the correct order from lowest to highest risk.
#
#     Low
#     Medium
#     High
#     Critical

# %% [markdown]
# Activity:
#
# | Cybersecurity Variable           | Example Value  | Data Type|
# | -------------------------------- | -------------- | ------------------------------- |
# | Number of failed login attempts  | 7              | discrete                      |
# | Packet arrival time              | 0.0023 seconds | continuous                      |
# | Number of alerts generated       | 24             | discrete                      |
# | CPU usage                        | 68.5%          | continuous                      |
# | Number of open ports             | 9              | discrete                      |
# | Network latency                  | 12.7 ms        | continuous                      |
# | Number of malware files detected | 3              | discrete                      |
# | Bandwidth usage                  | 125.8 Mbps     | continuous                      |
# | Number of users logged in        | 41             | discrete                      |
# | Memory utilization               | 73.2%          | continuous                      |

# %% [markdown]
# Activity: Classify
#
#     Qualitative / Quantitative
#     Nominal / Ordinal / Discrete / Continuous
#
# | Feature               | Classify    |
# | --------------------- |-------------|
# | Protocol              |Quality - Nominal |
# | Alert severity        |Quantity - Continuous|
# | Failed login attempts |Quantity - Discrete
# | Network latency       |Quantity - Continuous |
# | Attack type           |Quality - Nominal |
# | CPU utilization       |Quantity - Continuous |
# | Number of packets     |Quantity - Discrete |

# %% [markdown]
# Activity: Justify
#
# | Feature      | Classification | Justification              |
# | ------------ | -------------- | -------------------------- |
# | Severity     | Quantity - Continuous| Values can be in the decimal also|
# | Packet count | Quantity - Discrete| Packets can't be a decimal number|
# | Protocol     | Quality - Nominal | It includes names of it, all of them are equal we can't priorties them|

# %% [markdown]
# Activity: Fix the mistake
#
# | Feature        | Given Type   | Correct Type                               |
# | -------------- | ------------ | ------------------------------------------ |
# | Severity (1–5) | Quantitative |   Continuos            |
# | Packet size    | Discrete     |   Discrete                          |
# | Country        | Ordinal      |   Nominal                               |
# | Risk score     | Nominal      |   Continuous                         |

# %% [markdown]
# Activity: Differnt anlysis on the data

# %% [markdown]
# Activity: Valid or invalid

# %% [markdown]
# | Feature      | Operation | Valid? |
# | ------------ | --------- | ------ |
# | Protocol     | Average   |        |
# | Severity     | Rank      |        |
# | Packet count | Mean      |        |
# | Attack type  | Frequency |        |
