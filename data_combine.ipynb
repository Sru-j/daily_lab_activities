# %% [markdown]
# <a href="https://colab.research.google.com/github/Sru-j/Linux/blob/main/data_combine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing files from drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DIR = '/content/drive/My Drive/Colab Notebooks/day_10_data'
data_center ='superstore_central_dirty.csv'
data_east = 'superstore_east_dirty.csv'
data_north = 'superstore_north_dirty.csv'

# %%
import pandas as pd
filename_center = DIR+'/'+data_center
filename_east = DIR+'/'+data_east
filename_north = DIR+'/'+data_north
df_center = pd.read_csv(filename_center)
df_east = pd.read_csv(filename_east)
df_north = pd.read_csv(filename_north)

# %%
new_column_names = ['index','row_id','order_id','order_date','ship_date','ship_mode','customer_id','customer_name','segment','country','city','state','postal_code','region','product_id','category','sub_category','product_name','sales','qty','discount','profit','notes(dirty)']

# %% [markdown]
# # DF_CENTER Information

# %%
df_center
# Out:
#       Index   Row-ID       Order Id   order-date   Ship.Date      Ship  Mode  \
# 0         14    15.0  US-2015-118983  2015-11-22  11-26-2015  Standard Class
# 1         15    16.0  US-2015-118983  22/11/2015  2015-11-26  Standard Class
# 2         16    17.0  CA-2014-105893         NaN  18/11/2014  Standard Class
# 3         21    22.0  CA-2016-137330         NaN  12-13-2016  Standard Class
# 4         22    23.0  CA-2016-137330         NaN  13/12/2016  Standard Class
# ...      ...     ...             ...         ...         ...             ...
# 2341    1989  1990.0  CA-2015-127509         NaN  13/11/2015  Standard Class
# 2342    9485  9486.0  CA-2016-164770         NaN         NaN    Second Class
# 2343    8219  8220.0  CA-2014-120775         NaN         NaN  Standard Class
# 2344    8673  8674.0  CA-2017-163265  02-16-2017  02-21-2017  Standard Class
# 2345    6848  6849.0  US-2016-163461  06-18-2016  21/06/2016     First Class
#
# ...

# %%
df_center.shape
# Out:
# (2346, 23)

# %%
df_center.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2346 entries, 0 to 2345
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Index           2346 non-null   int64
#  1   Row-ID          2346 non-null   float64
#  2   Order Id        2346 non-null   object
#  3   order-date      1353 non-null   object
#  4   Ship.Date       1408 non-null   object
#  5   Ship  Mode      2346 non-null   object
#  6   CustomerID      2346 non-null   object
#  7   Customer  Name  2300 non-null   object
#  8   Segment         2346 non-null   object
#  9   Country         2346 non-null   object
#  10  City            2346 non-null   object
#  11  State           2346 non-null   object
#  12  Postal_Code#    2277 non-null   float64
#  13  REGION          2346 non-null   object
#  14  Product ID      2346 non-null   object
#  15  Category        2346 non-null   object
#  16  Sub Category    2346 non-null   object
# ...

# %%
df_center.describe()
# Out:
#             Index        Row-ID  Postal_Code#          Qty         disc
# count  2346.000000  2346.000000   2277.000000  2346.000000  2346.000000
# mean   5023.065644  5024.065644  65413.219587     3.777494     0.241236
# std    2929.924891  2929.924891  11418.979674     2.159903     0.266038
# min      14.000000    15.000000  46060.000000     1.000000     0.000000
# 25%    2523.250000  2524.250000  55407.000000     2.000000     0.000000
# 50%    5026.500000  5027.500000  65203.000000     3.000000     0.200000
# 75%    7612.750000  7613.750000  77041.000000     5.000000     0.300000
# max    9983.000000  9984.000000  79907.000000    14.000000     0.800000

# %%
df_center.columns
#column names have a space and dot in the names
# Out:
# Index(['Index ', 'Row-ID', 'Order Id ', 'order-date', 'Ship.Date',
#        'Ship  Mode', 'CustomerID', 'Customer  Name', 'Segment', 'Country',
#        'City', 'State', 'Postal_Code#', 'REGION', 'Product ID', 'Category',
#        'Sub Category', 'PRODUCT NAME', 'Sales($)', 'Qty', 'disc', 'Profit %',
#        'Notes (Dirty)'],
#       dtype='object')

# %%
df_center.columns = new_column_names
df_center.columns
# Out:
# Index(['index', 'row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'qty', 'discount', 'profit', 'notes(dirty)'],
#       dtype='object')

# %%
#is any column is null
df_center.isnull()
# Out:
#       index  row_id  order_id  order_date  ship_date  ship_mode  customer_id  \
# 0     False   False     False       False      False      False        False
# 1     False   False     False       False      False      False        False
# 2     False   False     False        True      False      False        False
# 3     False   False     False        True      False      False        False
# 4     False   False     False        True      False      False        False
# ...     ...     ...       ...         ...        ...        ...          ...
# 2341  False   False     False        True      False      False        False
# 2342  False   False     False        True       True      False        False
# 2343  False   False     False        True       True      False        False
# 2344  False   False     False       False      False      False        False
# 2345  False   False     False       False      False      False        False
#
# ...

# %%
df_center.isnull().sum()
# Out:
# index               0
# row_id              0
# order_id            0
# order_date        993
# ship_date         938
# ship_mode           0
# customer_id         0
# customer_name      46
# segment             0
# country             0
# city                0
# state               0
# postal_code        69
# region              0
# product_id          0
# category            0
# sub_category        0
# product_name        0
# sales              46
# qty                 0
# discount            0
# profit              0
# notes(dirty)     2295
# dtype: int64

# %%
#show data types of columns

df_center.dtypes
# Out:
# index              int64
# row_id           float64
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_id       object
# customer_name     object
# segment           object
# country           object
# city              object
# state             object
# postal_code      float64
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales            float64
# qty                int64
# discount         float64
# profit            object
# notes(dirty)      object
# dtype: object

# %%
df_center.head()
# Out:
#    index  row_id        order_id  order_date   ship_date       ship_mode  \
# 0     14    15.0  US-2015-118983  2015-11-22  11-26-2015  Standard Class
# 1     15    16.0  US-2015-118983  22/11/2015  2015-11-26  Standard Class
# 2     16    17.0  CA-2014-105893         NaN  18/11/2014  Standard Class
# 3     21    22.0  CA-2016-137330         NaN  12-13-2016  Standard Class
# 4     22    23.0  CA-2016-137330         NaN  13/12/2016  Standard Class
#
#   customer_id  customer_name      segment        country  ...   region  \
# 0    HP-14815  Harold Pawlan  Home Office  United States  ...  Central
# 1    HP-14815  Harold Pawlan  Home Office  United States  ...  Central
# 2    PK-19075      Pete Kriz     Consumer  United States  ...  Central
# 3    KB-16585      Ken Black    Corporate  United States  ...  Central
# 4    KB-16585      Ken Black    Corporate  United States  ...  Central
#
#         product_id         category sub_category  \
# ...

# %%
df_center.sample()
# Out:
#       index  row_id        order_id  order_date   ship_date       ship_mode  \
# 1921   8414  8415.0  CA-2016-147109  12-17-2016  12-21-2016  Standard Class
#
#      customer_id customer_name    segment        country  ...   region  \
# 1921    AH-10075     Adam Hart  Corporate  United States  ...  Central
#
#            product_id    category sub_category  \
# 1921  TEC-AC-10002942  Technology  Accessories
#
#                                            product_name  sales qty discount  \
# 1921  WD My Passport Ultra 1TB Portable External Har...  165.6   3      0.2
#
#       profit  notes(dirty)
# 1921   -6.21           NaN
#
# [1 rows x 23 columns]

# %% [markdown]
# data conversion

# %%
df_center.loc[2204, 'order_date'] = '2019-01-01'
df_center['order_date'][2204]
# Out:
# '2019-01-01'

# %%
df_center['order_date'][2204]
# Out:
# '2019-13-01'

# %%
df_center['order_date'] = df_center['order_date'].astype('datetime64[ns]')
df_center.dtypes['order_date']
# Out:
# dtype('<M8[ns]')

# %%
from os import replace
df_center['sales)'] = df_center['sales'].str.replace('$','')
df_center['sales'] = df_center['sales)'].str.replace(',','')
df_center['sales']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1784461533.py in <cell line: 0>()
#       1 from os import replace
# ----> 2 df_center['sales)'] = df_center['sales'].str.replace('$','')
#       3 df_center['sales'] = df_center['sales)'].str.replace(',','')
#       4 df_center['sales']
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
# ...

# %%
df_center.dtypes['sales']
df_center['sales'] = df_center['sales'].astype(float)
df_center.dtypes['sales']
# Out:
# dtype('float64')

# %%
df_center.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2341    False
# 2342     True
# 2343    False
# 2344    False
# 2345    False
# Length: 2346, dtype: bool

# %%
# Find duplicates based only on 'CustomerID' column
duplicates_subset = df_center[df_center.duplicated(subset=['CustomerID'], keep=False)]

print("\nDuplicate Rows (based on CustomerID):")
print(duplicates_subset)
# Out:
# Duplicate Rows (based on CustomerID):
#       Index   Row-ID       Order Id   order-date   Ship.Date      Ship  Mode  \
# 0         14    15.0  US-2015-118983  2015-11-22  11-26-2015  Standard Class
# 1         15    16.0  US-2015-118983  22/11/2015  2015-11-26  Standard Class
# 2         16    17.0  CA-2014-105893         NaN  18/11/2014  Standard Class
# 3         21    22.0  CA-2016-137330         NaN  12-13-2016  Standard Class
# 4         22    23.0  CA-2016-137330         NaN  13/12/2016  Standard Class
# ...      ...     ...             ...         ...         ...             ...
# 2341    1989  1990.0  CA-2015-127509         NaN  13/11/2015  Standard Class
# 2342    9485  9486.0  CA-2016-164770         NaN         NaN    Second Class
# 2343    8219  8220.0  CA-2014-120775         NaN         NaN  Standard Class
# 2344    8673  8674.0  CA-2017-163265  02-16-2017  02-21-2017  Standard Class
# 2345    6848  6849.0  US-2016-163461  06-18-2016  21/06/2016     First Class
#
# ...

# %%
# print the number of duplicate rows

count_duplicates = df_center.duplicated().sum()
print(f"Number of duplicate rows: {count_duplicates}")
# Out:
# Number of duplicate rows: 6

# %%
# print the duplicates

duplicates_only = df_center[df_center.duplicated(keep=False)]

print("Duplicate Rows Only:")
print(duplicates_only)
# Out:
# Duplicate Rows Only:
#       Index   Row-ID       Order Id   order-date   Ship.Date      Ship  Mode  \
# 178      674   675.0  CA-2017-130351         NaN         NaN     First Class
# 180      676   677.0  US-2017-119438  03-18-2017  03-23-2017  Standard Class
# 1473    6418  6419.0  CA-2016-140130  2016-10-31         NaN  Standard Class
# 1969    8571  8572.0  CA-2016-162222         NaN         NaN        Same Day
# 2197    9485  9486.0  CA-2016-164770         NaN         NaN    Second Class
# 2248    9687  9688.0  US-2017-130603         NaN         NaN  Standard Class
# 2326    8571  8572.0  CA-2016-162222         NaN         NaN        Same Day
# 2328     676   677.0  US-2017-119438  03-18-2017  03-23-2017  Standard Class
# 2329     674   675.0  CA-2017-130351         NaN         NaN     First Class
# 2338    9687  9688.0  US-2017-130603         NaN         NaN  Standard Class
# 2340    6418  6419.0  CA-2016-140130  2016-10-31         NaN  Standard Class
# ...

# %%
#print the duplicate values on customer

duplicates_only = df_center[df_center.duplicated(keep=False)]

print("Duplicate Rows Only:")
print(duplicates_only['CustomerID'])
# Out:
# Duplicate Rows Only:
# 178     RB-19570
# 180     CD-11980
# 1473    HW-14935
# 1969    SR-20740
# 2197    MY-18295
# 2248    SC-20050
# 2326    SR-20740
# 2328    CD-11980
# 2329    RB-19570
# 2338    SC-20050
# 2340    HW-14935
# 2342    MY-18295
# Name: CustomerID, dtype: object

# %%
# percentage of duplicates
total = len(df_center)
percentage = (count_duplicates/total)*100
print(f"Percentage of duplicates: {percentage:.2f}%")
# Out:
# Percentage of duplicates: 0.26%

# %%
#delete duplicates

df_cleaned = df_center.drop_duplicates()
df_cleaned.shape
# Out:
# (2340, 23)

# %% [markdown]
# # DF_EAST Information

# %%
df_east
# Out:
#        idx  row_id         order_id   OrderDate  ship_date         ShipMode  \
# 0       23       24  US-2017-156909  2017-07-16  2017-07-18    Second Class
# 1       27       28  US-2015-150630  09-17-2015  21/09/2015  Standard Class
# 2       28       29  US-2015-150630  09-17-2015  21/09/2015        Standard
# 3       29       30  US-2015-150630  2015-09-17  2015-09-21  Standard Class
# 4       30       31  US-2015-150630  2015-09-17  09-21-2015  Standard Class
# ...    ...      ...             ...         ...         ...             ...
# 2871  3913     3914  CA-2017-148068  18/09/2017  25/09/2017  Standard Class
# 2872  8205     8206  CA-2015-114811         NaN         NaN        Same Day
# 2873  9203     9204  CA-2016-153836  30/10/2016         NaN  Standard Class
# 2874   343      344  CA-2014-122336  2014-04-13  04-17-2014    Second Class
# 2875  4139     4140  CA-2017-127313         NaN         NaN     First Class
#
# ...

# %%
df_east.shape
# Out:
# (2876, 23)

# %%
df_east.columns
#columns don't have under score between the words
# Out:
# Index(['idx', 'row_id ', 'order_id', 'OrderDate', 'ship_date ', 'ShipMode',
#        'customer id', 'customer_name', 'Segment', 'Country', 'City', 'State',
#        'postalcode', 'region', 'Product ID', 'Category', 'sub_category',
#        'product_name', 'sales', 'quantity', 'discount', 'profit',
#        'Notes (Dirty)'],
#       dtype='object')

# %%
df_east.columns = new_column_names
df_east.columns
# Out:
# Index(['index', 'row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'qty', 'discount', 'profit', 'notes(dirty)'],
#       dtype='object')

# %%
df_east.dtypes
# Out:
# idx                int64
# row_id             int64
# order_id          object
# OrderDate         object
# ship_date         object
# ShipMode          object
# customer id       object
# customer_name     object
# Segment           object
# Country           object
# City              object
# State             object
# postalcode       float64
# region            object
# Product ID        object
# Category          object
# sub_category      object
# product_name      object
# sales             object
# quantity           int64
# discount         float64
# profit            object
# Notes (Dirty)     object
# dtype: object

# %%
df_east.isnull()
# Out:
#         idx  row_id   order_id  OrderDate  ship_date   ShipMode  customer id  \
# 0     False    False     False      False       False     False        False
# 1     False    False     False      False       False     False        False
# 2     False    False     False      False       False     False        False
# 3     False    False     False      False       False     False        False
# 4     False    False     False      False       False     False        False
# ...     ...      ...       ...        ...         ...       ...          ...
# 2871  False    False     False      False       False     False        False
# 2872  False    False     False       True        True     False        False
# 2873  False    False     False      False        True     False        False
# 2874  False    False     False      False       False     False        False
# 2875  False    False     False       True        True     False        False
#
# ...

# %%
df_east.isnull().sum()
# Out:
# idx                 0
# row_id              0
# order_id            0
# OrderDate        1189
# ship_date        1127
# ShipMode            0
# customer id         0
# customer_name      57
# Segment             0
# Country             0
# City                0
# State               0
# postalcode         86
# region              0
# Product ID          0
# Category            0
# sub_category        0
# product_name        0
# sales              56
# quantity            0
# discount            0
# profit              0
# Notes (Dirty)    2820
# dtype: int64

# %%
df_east.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2871    False
# 2872    False
# 2873     True
# 2874    False
# 2875    False
# Length: 2876, dtype: bool

# %%
# print the number of duplicate rows

count_duplicates = df_east.duplicated().sum()
print(f"Number of duplicate rows: {count_duplicates}")
# Out:
# Number of duplicate rows: 4

# %%
# print the duplicates

duplicates_only = df_center[df_east.duplicated(keep=False)]

print("Duplicate Rows Only:")
print(duplicates_only)
# Out:
# Duplicate Rows Only:
#       Index   Row-ID       Order Id   order-date   Ship.Date      Ship  Mode  \
# 128      467   468.0  US-2015-101399  01-17-2015  24/01/2015  Standard Class
# 327     1446  1447.0  CA-2017-102337  06-13-2017  2017-06-16     First Class
# 1664    7282  7283.0  CA-2017-155936  22/06/2017  06-29-2017  Standard Class
#
#      CustomerID   Customer  Name      Segment        Country  ...   REGION  \
# 128    JS-15940  Joni Sundaresam  Home Office  United States  ...  Central
# 327    SD-20485  Shirley Daniels  Home Office  United States  ...  Central
# 1664   JK-15730    Joe Kamberova     Consumer  United States  ...  Central
#
#            Product ID         Category Sub Category  \
# 128   FUR-FU-10002918        Furniture  Furnishings
# 327   FUR-CH-10004289        Furniture       Chairs
# 1664  OFF-BI-10002432  Office Supplies      Binders
#
#                                            PRODUCT NAME Sales($) Qty disc  \
# ...

# %%
#print the duplicate values on customer

duplicates_only = df_east[df_east.duplicated(keep=False)]

print("Duplicate Rows Only:")
print(duplicates_only['customer id'])
# Out:
# Duplicate Rows Only:
# 128     DK-13225
# 327     LA-16780
# 1664    RS-19420
# 2596    EH-13765
# 2854    LA-16780
# 2855    RS-19420
# 2859    DK-13225
# 2873    EH-13765
# Name: customer id, dtype: object

# %%
# percentage of duplicates
total = len(df_east)
percentage = (count_duplicates/total)*100
print(f"Percentage of duplicates: {percentage:.2f}%")
# Out:
# Percentage of duplicates: 0.14%

# %%
#delete duplicates

df_cleaned = df_east.drop_duplicates()
df_cleaned.shape
# Out:
# (2872, 23)

# %% [markdown]
# # DF_NORTH Information

# %%
df_north
# Out:
#       unnamed_col  RowId        ORDER-ID  ORDER DATE    ShipDate  \
# 0            9611   9612  CA-2017-144365  24/10/2017  10-30-2017
# 1            2404   2405  CA-2017-108574         NaN         NaN
# 2            2476   2477  CA-2016-114972         NaN         NaN
# 3            8698   8699  CA-2017-119284  2017-06-15  2017-06-20
# 4            9685   9686  CA-2017-118668         NaN         NaN
# ...           ...    ...             ...         ...         ...
# 2621         6512   6513  CA-2017-167640         NaN         NaN
# 2622          576    577  CA-2015-149713  18/09/2015  09-22-2015
# 2623          338    339  CA-2014-129924         NaN  07-17-2014
# 2624         8751   8752  CA-2016-105662         NaN         NaN
# 2625         9501   9502  US-2015-158589  20/11/2015  11-24-2015
#
#            SHIP_MODE   CUST-ID      CUSTOMER NAME      Segment        Country  \
# 0     Standard Class  CS-11950     Carlos Soltero     Consumer  United States
# ...

# %%
df_north.shape
# Out:
# (2626, 23)

# %%
df_north.columns
#column names are in title format with no space between the words
# Out:
# Index(['unnamed_col', 'RowId', 'ORDER-ID', 'ORDER DATE', 'ShipDate',
#        'SHIP_MODE', 'CUST-ID', 'CUSTOMER NAME', 'Segment', 'Country', 'City',
#        'State', 'Postal Code ', 'Region ', 'Product ID', 'Category',
#        'SubCategory', 'Product  Name', 'Sales USD', 'QTY ', 'Discount%',
#        'PROFIT($)', 'Notes (Dirty)'],
#       dtype='object')

# %%
df_north.columns = new_column_names
df_north.columns
# Out:
# Index(['index', 'row_id', 'order_id', 'order_date', 'ship_date', 'ship_mode',
#        'customer_id', 'customer_name', 'segment', 'country', 'city', 'state',
#        'postal_code', 'region', 'product_id', 'category', 'sub_category',
#        'product_name', 'sales', 'qty', 'discount', 'profit', 'notes(dirty)'],
#       dtype='object')

# %%
df_north.dtypes
# Out:
# unnamed_col        int64
# RowId              int64
# ORDER-ID          object
# ORDER DATE        object
# ShipDate          object
# SHIP_MODE         object
# CUST-ID           object
# CUSTOMER NAME     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# SubCategory       object
# Product  Name     object
# Sales USD         object
# QTY                int64
# Discount%        float64
# PROFIT($)         object
# Notes (Dirty)     object
# dtype: object

# %%
df_north.isnull()
# Out:
#       unnamed_col  RowId  ORDER-ID  ORDER DATE  ShipDate  SHIP_MODE  CUST-ID  \
# 0           False  False     False       False     False      False    False
# 1           False  False     False        True      True      False    False
# 2           False  False     False        True      True      False    False
# 3           False  False     False       False     False      False    False
# 4           False  False     False        True      True      False    False
# ...           ...    ...       ...         ...       ...        ...      ...
# 2621        False  False     False        True      True      False    False
# 2622        False  False     False       False     False      False    False
# 2623        False  False     False        True     False      False    False
# 2624        False  False     False        True      True      False    False
# 2625        False  False     False       False     False      False    False
#
# ...

# %%
df_north.isnull().sum()
# Out:
# unnamed_col         0
# RowId               0
# ORDER-ID            0
# ORDER DATE       1079
# ShipDate          992
# SHIP_MODE           0
# CUST-ID             0
# CUSTOMER NAME      52
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code        78
# Region              0
# Product ID          0
# Category            0
# SubCategory         0
# Product  Name       0
# Sales USD          53
# QTY                 0
# Discount%           0
# PROFIT($)           0
# Notes (Dirty)    2586
# dtype: int64

# %%
df_north.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2621     True
# 2622    False
# 2623    False
# 2624    False
# 2625    False
# Length: 2626, dtype: bool

# %%
# print the number of duplicate rows

count_duplicates = df_north.duplicated().sum()
print(f"Number of duplicate rows: {count_duplicates}")
# Out:
# Number of duplicate rows: 2

# %%
# print the duplicates

duplicates_only = df_north[df_north.duplicated(keep=False)]

print("Duplicate Rows Only:")
print(duplicates_only)
# Out:
# Duplicate Rows Only:
#       unnamed_col  RowId        ORDER-ID ORDER DATE    ShipDate  \
# 134          6512   6513  CA-2017-167640        NaN         NaN
# 837          7015   7016  CA-2014-114790        NaN  03-13-2014
# 2608         7015   7016  CA-2014-114790        NaN  03-13-2014
# 2621         6512   6513  CA-2017-167640        NaN         NaN
#
#            SHIP_MODE   CUST-ID   CUSTOMER NAME      Segment        Country  \
# 134   Standard Class  FC-14245  Frank Carlisle  Home Office  United States
# 837     Second Class  FM-14215   Filia McAdams    Corporate  United States
# 2608    Second Class  FM-14215   Filia McAdams    Corporate  United States
# 2621  Standard Class  FC-14245  Frank Carlisle  Home Office  United States
#
#       ... Region        Product ID         Category  SubCategory  \
# 134   ...   North  OFF-LA-10004559  Office Supplies       Labels
# 837   ...   North  TEC-AC-10000710       Technology  Accessories
# ...

# %%
#print the duplicate values on customer

duplicates_only = df_north[df_north.duplicated(keep=False)]

print("Duplicate Rows Only:")
print(duplicates_only['CUST-ID'])
# Out:
# Duplicate Rows Only:
# 134     FC-14245
# 837     FM-14215
# 2608    FM-14215
# 2621    FC-14245
# Name: CUST-ID, dtype: object

# %%
# percentage of duplicates
total = len(df_north)
percentage = (count_duplicates/total)*100
print(f"Percentage of duplicates: {percentage:.2f}%")
# Out:
# Percentage of duplicates: 0.08%

# %%
#delete duplicates

df_cleaned = df_north.drop_duplicates()
df_cleaned.shape
# Out:
# (2624, 23)
